# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
from numpy.fft import fft2, fftshift

# %%
# 画像を読み込む
image = imread('../data/Hadamard64_input/hadamard_130.png')

# グレースケール画像に変換（もしカラー画像なら）
if image.ndim == 3:
    image = image.mean(axis=2)

# %%
# 2次元フーリエ変換を実行
f_image = fft2(image)

# 中心にシフト
f_shifted = fftshift(f_image)

# パワースペクトルを計算
magnitude_spectrum = 20*np.log(np.abs(f_shifted))
# Out:
# C:\Users\ohara\AppData\Local\Temp\ipykernel_19580\1143968222.py:8: RuntimeWarning: divide by zero encountered in log
#   magnitude_spectrum = 20*np.log(np.abs(f_shifted))

# %%
# 元の画像を表示
plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])

# 周波数領域の画像を表示
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.show()
